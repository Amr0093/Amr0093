# %% [markdown]
# <a href="https://colab.research.google.com/github/Amr0093/Amr0093/blob/main/diabetes_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, ShuffleSplit

# %%
diabetes_data = load_diabetes()

# %%
diabetes_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
X = diabetes_data['data']
y = diabetes_data['target']
X.shape
# Out:
# (442, 10)

# %%
data, test, data_target, test_target =train_test_split(X, y,shuffle=True, test_size=0.3)
train, vale, train_target, val_target =train_test_split(data, data_target,shuffle=True, test_size=0.3)

# %%
LR_Model = LinearRegression()

# %%
LR_Model.fit(train, train_target)
# Out:
# LinearRegression()

# %%
LR_Model.score(train ,train_target)
# Out:
# 0.4756952052072475

# %% [markdown]
# # the train result is very low so the data model used may under fit and to be tuned

# %%
train.shape # the feature of train has x1,x2,x2 .......x10
# Out:
# (216, 10)

# %%
prediction = LR_Model.predict(vale)
prediction.shape, prediction.shape
# Out:
# ((93,), (93,))

# %%
LR_Model.score(vale ,prediction)
# Out:
# 1.0

# %%
LR_Model.score(vale,prediction)
# Out:
# 1.0

# %%
test_prediction = LR_Model.predict(test)

# %%
LR_Model.score(test,test_prediction)
# Out:
# 1.0

# %%
plt.scatter(train[:,1],train_target, color="red")

plt.plot(vale, prediction, color="k")

plt.title("Linear Fit diabetes")
plt.xlabel("feature")
plt.ylabel("target")

plt.show()

# %% [markdown]
# polynomial fit phas

# %%
poly_model = LinearRegression()
poly_model.fit(train, train_target)
poly_model.score(train, train_target)
# Out:
# 0.4756952052072475

# %%
poly_predicitons = poly_model.predict(vale)
poly_model.score(vale, poly_predicitons)
# Out:
# 1.0

# %%
poly_test_predicitons = poly_model.predict(test)
poly_model.score(test, poly_test_predicitons)
# Out:
# 1.0

# %%
train.shape,train_target.shape
# Out:
# ((216, 10), (216,))

# %%
plt.scatter(train[:,1],train_target, color="red")

plt.plot(vale, poly_predicitons, color="k")

plt.title("Poly fit diabetes")
plt.xlabel("feature")
plt.ylabel("target")

plt.show()
